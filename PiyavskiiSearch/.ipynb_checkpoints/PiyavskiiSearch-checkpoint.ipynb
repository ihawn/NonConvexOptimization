# %% [markdown]
# ### Piyavskii Search is an alternative to line search and will find the true min along the search plane

# %% [markdown]
# ### 2-D Objective

# %%
using Plots, Zygote, LinearAlgebra

# %%
SawTooth(x1, x2, z1, z2, L) = (z1 - z2)/2L + (x1 + x2)/2.0, (z1 + z2)/2 + L*(x1 - x2)/2

function Piyavskii(f, a, b, L, ϵ, m)
    fa = f(a); fb = f(b)
    x, y = SawTooth(a, b, fa, fb, L)

    x_list = [a, x, b]
    y_list = [fa, y, fb]
    X = [a, b]
    Y = [fa, fb]
    α_list = Float64[]
    β_list = Float64[]
    minpos = 0

    for i = 1:m
        minpos = argmin(y_list)
        y_list[minpos] = f(x_list[minpos])

        for j = 1:2
            pos1 = minpos - j%2
            pos2 = minpos + (j+1)%2
            x, y = SawTooth(x_list[pos1], x_list[pos2], y_list[pos1], y_list[pos2], L)
            append!(x_list, x); append!(y_list, y);
            append!(X, x)
            append!(Y, f(x))
        end

        p = sortperm(x_list); permute!(x_list, p); permute!(y_list, p)

        α = minimum(y_list)
        β, minpos = findmin(Y)
        append!(α_list, α); append!(β_list, β)


        if abs(β - α) <= ϵ        
            break
        end
    end

    x = X[minpos]
    y = Y[minpos]

    return x, y, x_list, y_list, α_list, β_list
end
# Out:
# Piyavskii (generic function with 1 method)

# %%
x1 = [-1.9, (rand() - 0.5)*4]
x2 = [1.9, (rand() - 0.5)*4]

f(x,y) = x*sin(10*y) + y*cos(10*x) + 0.5*x^2 + 0.5*y^2
f(x) = f(x...)
# Out:
# f (generic function with 2 methods)

# %%
aa = -2:.02:2
bb = -2:.02:2

contour(aa, bb, f, fill=false, colorbar = false, dpi = 100, title = "Piyavskii Search Problem: Minimize f Along the Line")
plot!(size=(600,600), legend=:none)

plot!([x1[1], x2[1]], [x1[2], x2[2]], color=:blue, label = false)
scatter!([x1[1]], [x1[2]], color=:green, label = "x1")
scatter!([x2[1]], [x2[2]], color=:green, label = "x2")

# %%
ell(t) = x1 + t*(x2 - x1)
phi(t) = f(ell(t))
# Out:
# phi (generic function with 1 method)

# %%
projectedMin = Piyavskii(phi, 0.0, 1.0, 12.0, 1e-5, 5000);

# %%
aa = -2:.02:2
bb = -2:.02:2

contour(aa, bb, f, fill=false, colorbar = false, dpi = 100, title = "Piyavskii Search Solution")
plot!(size=(600,600))

plot!([x1[1], x2[1]], [x1[2], x2[2]], color=:blue, label = false)
scatter!([x1[1]], [x1[2]], color=:green, label = "x1")
scatter!([x2[1]], [x2[2]], color=:green, label = "x2")
ℓ = ell(projectedMin[1])
scatter!([ℓ[1]], [ℓ[2]], color=:red, label = "Solution")

# %%
plot(phi, xrange = (0, 1), title = "Piyavskii Search Solution as a Slice", label = false, xlabel = "t")
scatter!([projectedMin[1]], [phi(projectedMin[1])], color=:red, label = "Min")

# %% [markdown]
# ### N-D Objective

# %%
n = 50

x1 = (rand(n) .- 0.5)*10
x2 = (rand(n) .- 0.5)*10
x1[1] = -5
x2[1] = 5

f(x) = sum(sin(x[i])*sin(i*x[i]^2/pi)^5 for i in 1:n) #Michalewicz Function
# Out:
# f (generic function with 2 methods)

# %%
ell(t) = x1 + t*(x2 - x1)
phi(t) = f(ell(t))
# Out:
# phi (generic function with 1 method)

# %%
L = -Inf
for i in 1:1000
    fp = phi'((rand()-0.5)*10)
    if(fp > L)
        L = fp
    end
end
L *= 1.3

projectedMin = Piyavskii(phi, 0.0, 1.0, L, 1e-5, 5000);

# %%
title_string = string("Piyavskii Search Solution as a Slice of ", n, "-D Objective")
plot(phi, xrange = (0, 1), title = title_string, label = false, xlabel = "t")
scatter!([projectedMin[1]], [phi(projectedMin[1])], color=:red, label = "Min")

# %% [markdown]
# ### Replacing backtracking line search in Gradient Descent with Piyavskii Search

# %%
function Back_Line_Search(_x, _f, _fx, _∇f, _Δx, _α, _β, _κ)
    _t = _κ

    while _f(_x + _t*_Δx) > _fx + _α*_t*transpose(_∇f)*_Δx && _t > 1e-8
        _t *= _β
    end

    return _t
end

function Piyavskii_Search(_x, _f, _fx, _∇f, _Δx, _L, _κ)
    _t = _κ
    phi(t) = _f(_x + t*_Δx)
    piya_sol = Piyavskii(phi, 0.0, 1.0, _L, 1e-4, 50)
    return piya_sol[1]
end
# Out:
# Piyavskii_Search (generic function with 1 method)

# %%
function Grad_Descent(_f, _x, _α, _β, _ϵ, _κ, _L, maxIt, use_piyavskii_search)
    xtrace = [_x]
    
    it = 0;
    t = 1
    ∇f = _f'(_x)
    normGrad = norm(∇f)
    val = _f(_x)
    
    while normGrad > _ϵ && it < maxIt
        ∇f = _f'(_x)
        normGrad = norm(∇f)

        bls = use_piyavskii_search ? Piyavskii_Search(_x, _f, val, ∇f, -∇f, _L, _κ) : Back_Line_Search(_x, _f, val, ∇f, -∇f, _α, _β, _κ)
        t = bls[1]
        _x -= t*∇f
        val = _f(_x)

        it+=1
        push!(xtrace, _x)
    end
    return _x, val, xtrace
end
# Out:
# Grad_Descent (generic function with 1 method)

# %%
f(x) = x[1]*sin(10*x[2]) + x[2]*cos(10*x[1]) + 0.5*x[1]^2 + 0.5*x[2]^2
f(x, y) = f(x...)

x0 = [2.0, 2.0]
α = 0.5
β = 0.8
κ = 1
ϵ = 1e-8
L = 500

sol = Grad_Descent(f, x0, α, β, ϵ, κ, L, 1e2, true);

# %%
xx = yy = -3:0.01:3
contour(xx, yy, f, dpi = 100, colorbar = false, legend =:topleft, aspect_ratio=:equal)
plot!([sol[3][i][1] for i in 1:length(sol[3])], [sol[3][i][2] for i in 1:length(sol[3])], color=:black, label = false)
scatter!([sol[3][i][1] for i in 1:length(sol[3])], [sol[3][i][2] for i in 1:length(sol[3])], color=:green, label = false)
scatter!([sol[1][1]], [sol[1][2]], color =:red, label = "Solution")
# Out:
# BoundsError
#
# Stacktrace:
#   [1] getindex
#     @ .\number.jl:98 [inlined]
#   [2] f(x::Float64)
#     @ Main .\In[80]:1
#   [3] f
#     @ .\In[80]:2 [inlined]
#   [4] Surface(f::typeof(f), x::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, y::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64})
#     @ RecipesPipeline C:\Users\Isaac\.julia\packages\RecipesPipeline\F2mWY\src\utils.jl:77
#   [5] macro expansion
#     @ C:\Users\Isaac\.julia\packages\RecipesPipeline\F2mWY\src\user_recipe.jl:278 [inlined]
#   [6] apply_recipe(plotattributes::AbstractDict{Symbol, Any}, x::AbstractVector, y::AbstractVector, zf::Function)
#     @ RecipesPipeline C:\Users\Isaac\.julia\packages\RecipesBase\qpxEX\src\RecipesBase.jl:289
#   [7] _process_userrecipes!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline C:\Users\Isaac\.julia\packages\RecipesPipeline\F2mWY\src\user_recipe.jl:36
#   [8] recipe_pipeline!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline C:\Users\Isaac\.julia\packages\RecipesPipeline\F2mWY\src\RecipesPipeline.jl:70
#   [9] _plot!(plt::Plots.Plot, plotattributes::Any, args::Any)
#     @ Plots C:\Users\Isaac\.julia\packages\Plots\rDbWY\src\plot.jl:208
#  [10] #plot#139
#     @ C:\Users\Isaac\.julia\packages\Plots\rDbWY\src\plot.jl:91 [inlined]
#  [11] contour(::Any, ::Vararg{Any}; kw::Base.Pairs{Symbol, V, Tuple{Vararg{Symbol, N}}, NamedTuple{names, T}} where {V, N, names, T<:Tuple{Vararg{Any, N}}})
#     @ Plots C:\Users\Isaac\.julia\packages\RecipesBase\qpxEX\src\RecipesBase.jl:410
#  [12] top-level scope
#     @ In[81]:2
#  [13] eval
#     @ .\boot.jl:373 [inlined]
#  [14] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:1196

# %%
n = 2

Michalewicz(x) = sum(sin(x[i])*sin(i*x[i]^2/pi)^5 for i in 1:n)

x0 = [5.0, 5.0]
α = 0.5
β = 0.8
κ = 1
ϵ = 1e-8
L = 500

sol = Grad_Descent(Michalewicz, x0, α, β, ϵ, κ, L, 1e2, true)
# Out:
# ([4.962197215059513, 4.978323046338425], -0.9683297692852288, [[5.0, 5.0], [4.958356203096714, 4.998772762276177], [4.962763777811848, 4.997691063599752], [4.961200757059372, 4.995484843771387], [4.962336848486881, 4.994781532465381], [4.961160808297947, 4.990535539704362], [4.962343009831423, 4.99020710154665], [4.961792428365683, 4.9892755305605], [4.962245171519581, 4.989012059782767], [4.961658113120704, 4.986918799944431]  …  [4.962159868898403, 4.978609942461223], [4.962197389882721, 4.978584925622586], [4.962166943290475, 4.9785477303722026], [4.962200217845212, 4.978517139866771], [4.9621693983731365, 4.978486879900248], [4.962197943942101, 4.978456944264973], [4.962166216654279, 4.978421403449396], [4.962193956015753, 4.9783980092455895], [4.9621601920733855, 4.978345812612438], [4.962197215059513, 4.978323046338425]])

# %%
f(x, y) = Michalewicz([x, y])
xx = yy = -10:0.1:10
contour(xx, yy, f, dpi = 100, colorbar = false, legend =:topleft, aspect_ratio=:equal)
plot!([sol[3][i][1] for i in 1:length(sol[3])], [sol[3][i][2] for i in 1:length(sol[3])], color=:black, label = false)
scatter!([sol[3][i][1] for i in 1:length(sol[3])], [sol[3][i][2] for i in 1:length(sol[3])], color=:green, label = false)
scatter!([sol[1][1]], [sol[1][2]], color =:red, label = "Solution")
